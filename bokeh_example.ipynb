# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# %%
num = 4000
x = np.random.random(size=num) * 100
y = np.random.random(size=num) * 100
radii = np.random.random(size=num) * 1.5

colors = ['#%02x%02x%02x' %(r,g,150) for r,g in zip(np.floor(50+2*x).astype(int),np.floor(30+2*y).astype(int) )]

# %%
output_notebook()

p=figure()
p.circle(x,y,radius=radii,fill_color=colors,fill_alpha=0.6,line_color=None)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1572">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c02d7561-23d4-419e-a0ab-863d33500990" data-root-id="1573"></div>
